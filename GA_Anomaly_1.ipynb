# %%
import requests

# %%
def get_json_for_state(state):

    url = f'https://static01.nyt.com/elections-assets/2020/data/api/2020-11-03/state-page/{state}.json'
    r = requests.get(url)
    if r.status_code == 200:
        return r.json()
    else:
        print(
            f"Something went wrong with state {state}. I'm outputing the raw response")
        return r

# %%
california_json = get_json_for_state('georgia')['data']

# %%
pres_race = list(filter(lambda x: x["race_name"] == "President", california_json['races']))[0]

# %%
pres_race.keys()
# Out:
# dict_keys(['race_id', 'race_slug', 'url', 'state_page_url', 'ap_polls_page', 'edison_exit_polls_page', 'race_type', 'election_type', 'election_date', 'runoff', 'race_name', 'office', 'officeid', 'nyt_race_description', 'race_rating', 'seat', 'seat_name', 'state_id', 'state_slug', 'state_name', 'state_nyt_abbrev', 'state_shape', 'state_aspect_ratio', 'party_id', 'uncontested', 'report', 'result', 'result_source', 'gain', 'lost_seat', 'votes', 'electoral_votes', 'absentee_votes', 'absentee_counties', 'absentee_count_progress', 'absentee_outstanding', 'absentee_max_ballots', 'provisional_outstanding', 'provisional_count_progress', 'poll_display', 'poll_countdown_display', 'poll_waiting_display', 'poll_time', 'poll_time_short', 'precincts_reporting', 'precincts_total', 'reporting_display', 'reporting_value', 'eevp', 'tot_exp_vote', 'eevp_source', 'eevp_value', 'eevp_display', 'county_data_source', 'incumbent_party', 'no_forecast', 'last_updated', 'candidates', 'has_incumbent', 'leader_margin_value', 'leader_margin_votes', 'leader_margin_display', 'leader_margin_name_display', 'leader_party_id', 'counties', 'precinct_metadata', 'votes2016', 'margin2016', 'clinton2016', 'trump2016', 'votes2012', 'margin2012', 'expectations_text', 'expectations_text_short', 'absentee_ballot_deadline', 'absentee_postmark_deadline', 'update_sentences', 'race_diff', 'winnerCalledTimestamp', 'model_metadata', 'timeseries'])

# %%
pres_timeseries = pres_race["timeseries"]
pres_timeseries[0]
# Out:
# {'vote_shares': {'trumpd': 0, 'bidenj': 0},
#  'votes': 0,
#  'eevp': 0,
#  'eevp_source': 'edison',
#  'timestamp': '2020-11-04T09:23:03Z'}

# %%
total_djt_diff = 0
total_jrb_diff = 0

# %%
def print_discrepancy(before_id):
    global total_djt_diff, total_jrb_diff
    
    before_update = pres_timeseries[before_id]
    after_update = pres_timeseries[before_id+1]
    
    votes_djt_before = round(before_update["vote_shares"]["trumpd"] * before_update["votes"])
    votes_jrb_before = round(before_update["vote_shares"]["bidenj"] * before_update["votes"])
    votes_djt_after = round(after_update["vote_shares"]["trumpd"] * after_update["votes"])
    votes_jrb_after = round(after_update["vote_shares"]["bidenj"] * after_update["votes"])

    diff_djt = votes_djt_after - votes_djt_before
    diff_jrb = votes_jrb_after - votes_jrb_before
    diff_total = after_update["votes"] - before_update["votes"]
    
    total_djt_diff += diff_djt
    total_jrb_diff += diff_jrb
    
    
    print("DISCREPANCY DETECTED:\n")
    print("DJT VOTES BEFORE: {}".format(votes_djt_before))
    print("JRB VOTES BEFORE: {}".format(votes_jrb_before))
    print("TOTAL BEFORE: {}".format(before_update["votes"]))
    print("TIMESTAMP BEFORE: {}\n".format(before_update["timestamp"]))

    print("DJT VOTES AFTER: {}".format(votes_djt_after))
    print("JRB VOTES AFTER: {}".format(votes_jrb_after))
    print("TOTAL AFTER: {}".format(after_update["votes"]))
    print("TIMESTAMP AFTER: {}\n".format(after_update["timestamp"]))


    print("DJT DIFF: {}".format(diff_djt))
    print("JRB DIFF: {}".format(diff_jrb))
    print("TOTAL DIFF: {}".format(diff_total))
    print("===================================")

# %%
for i,update in enumerate(pres_timeseries):
    before_update = pres_timeseries[i]
    after_update = pres_timeseries[i+1]
    
    # Calculate vote counts
    votes_djt_before = round(before_update["vote_shares"]["trumpd"] * before_update["votes"])
    votes_jrb_before = round(before_update["vote_shares"]["bidenj"] * before_update["votes"])
    votes_djt_after = round(after_update["vote_shares"]["trumpd"] * after_update["votes"])
    votes_jrb_after = round(after_update["vote_shares"]["bidenj"] * after_update["votes"])
    
    if((votes_djt_after < votes_djt_before) or (votes_jrb_after < votes_jrb_before)):
        print_discrepancy(i)
    
    if(i==len(pres_timeseries)-2):
        break
# Out:
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 76065
# JRB VOTES BEFORE: 97272
# TOTAL BEFORE: 175264
# TIMESTAMP BEFORE: 2020-11-04T00:23:58Z
#
# DJT VOTES AFTER: 76370
# JRB VOTES AFTER: 97262
# TOTAL AFTER: 175564
# TIMESTAMP AFTER: 2020-11-04T00:24:14Z
#
# DJT DIFF: 305
# JRB DIFF: -10
# TOTAL DIFF: 300
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 148450
# JRB VOTES BEFORE: 132302
# TOTAL BEFORE: 283301
# TIMESTAMP BEFORE: 2020-11-04T00:47:05Z
#
# DJT VOTES AFTER: 148480
# JRB VOTES AFTER: 132045
# TOTAL AFTER: 283359
# TIMESTAMP AFTER: 2020-11-04T00:47:52Z
#
# DJT DIFF: 30
# JRB DIFF: -257
# TOTAL DIFF: 58
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 424199
# JRB VOTES BEFORE: 349203
# TOTAL BEFORE: 781214
# TIMESTAMP BEFORE: 2020-11-04T01:13:56Z
#
# DJT VOTES AFTER: 425236
# JRB VOTES AFTER: 348631
# TOTAL AFTER: 781684
# TIMESTAMP AFTER: 2020-11-04T01:14:54Z
#
# DJT DIFF: 1037
# JRB DIFF: -572
# TOTAL DIFF: 470
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 425236
# JRB VOTES BEFORE: 348631
# TOTAL BEFORE: 781684
# TIMESTAMP BEFORE: 2020-11-04T01:14:54Z
#
# DJT VOTES AFTER: 424789
# JRB VOTES AFTER: 348906
# TOTAL AFTER: 782301
# TIMESTAMP AFTER: 2020-11-04T01:15:55Z
#
# DJT DIFF: -447
# JRB DIFF: 275
# TOTAL DIFF: 617
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE:
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2410219
# JRB VOTES BEFORE: 2342868
# TOTAL BEFORE: 4810817
# TIMESTAMP BEFORE: 2020-11-04T22:51:51Z
#
# DJT VOTES AFTER: 2410095
# JRB VOTES AFTER: 2352253
# TOTAL AFTER: 4820190
# TIMESTAMP AFTER: 2020-11-04T22:52:13Z
#
# DJT DIFF: -124
# JRB DIFF: 9385
# TOTAL DIFF: 9373
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2429076
# JRB VOTES BEFORE: 2390055
# TOTAL BEFORE: 4877663
# TIMESTAMP BEFORE: 2020-11-05T02:16:50Z
#
# DJT VOTES AFTER: 2427462
# JRB VOTES AFTER: 2388466
# TOTAL AFTER: 4874421
# TIMESTAMP AFTER: 2020-11-05T02:50:36Z
#
# DJT DIFF: -1614
# JRB DIFF: -1589
# TOTAL DIFF: -3242
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2427462
# JRB VOTES BEFORE: 2388466
# TOTAL BEFORE: 4874421
# TIMESTAMP BEFORE: 2020-11-05T02:50:36Z
#
# DJT VOTES AFTER: 2426781
# JRB VOTES AFTER: 2387797
# TOTAL AFTER: 4873055
# TIMESTAMP AFTER: 2020-11-05T02:54:08Z
#
# DJT DIFF: -681
# JRB DIFF: -669
# TOTAL DIFF: -1366
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2426781
# JRB VOTES BEFORE: 2387797
# TOTAL BEFORE: 4873055
# TIMESTAMP BEFORE: 2020-11-05T02:54:08Z
#
# DJT VOTES AFTER: 2425228
# JRB VOTES AFTER: 2391070
# TOTAL AFTER: 4879735
# TIMESTAMP AFTER: 2020-11-05T03:00:29Z
#
# DJT DIFF: -1553
# JRB DIFF: 3273
# TOTAL DIFF: 6680
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2428943
# JRB VOTES BEFORE: 2399620
# TOTAL BEFORE: 4887209
# TIMESTAMP BEFORE: 2020-11-05T05:23:50Z
#
# DJT VOTES AFTER: 2426440
# JRB VOTES AFTER: 2401980
# TOTAL AFTER: 4892017
# TIMESTAMP AFTER: 2020-11-05T06:06:21Z
#
# DJT DIFF: -2503
# JRB DIFF: 2360
# TOTAL DIFF: 4808
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2434850
# JRB VOTES BEFORE: 2415214
# TOTAL BEFORE: 4908971
# TIMESTAMP BEFORE: 2020-11-05T15:48:46Z
#
# DJT VOTES AFTER: 2432975
# JRB VOTES AFTER: 2418230
# TOTAL AFTER: 4915101
# TIMESTAMP AFTER: 2020-11-05T16:33:27Z
#
# DJT DIFF: -1875
# JRB DIFF: 3016
# TOTAL DIFF: 6130
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 2451167
# JRB VOTES BEFORE: 2451167
# TOTAL BEFORE: 4961877
# TIMESTAMP BEFORE: 2020-11-06T21:59:41Z
#
# DJT VOTES AFTER: 2449694
# JRB VOTES AFTER: 2454663
# TOTAL AFTER: 4968953
# TIMESTAMP AFTER: 2020-11-06T22:00:40Z
#
# DJT DIFF: -1473
# JRB DIFF: 3496
# TOTAL DIFF: 7076
# ===================================

# %%
print("TOTAL DJT DIFF: {}".format(total_djt_diff))
print("TOTAL JRB DIFF: {}".format(total_jrb_diff))
# Out:
# TOTAL DJT DIFF: 807
# TOTAL JRB DIFF: 22849
