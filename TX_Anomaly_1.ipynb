# %%
import requests

# %%
def get_json_for_state(state):

    url = f'https://static01.nyt.com/elections-assets/2020/data/api/2020-11-03/state-page/{state}.json'
    r = requests.get(url)
    if r.status_code == 200:
        return r.json()
    else:
        print(
            f"Something went wrong with state {state}. I'm outputing the raw response")
        return r

# %%
california_json = get_json_for_state('texas')['data']

# %%
pres_race = list(filter(lambda x: x["race_name"] == "President", california_json['races']))[0]

# %%
pres_race.keys()
# Out:
# dict_keys(['race_id', 'race_slug', 'url', 'state_page_url', 'ap_polls_page', 'edison_exit_polls_page', 'race_type', 'election_type', 'election_date', 'runoff', 'race_name', 'office', 'officeid', 'nyt_race_description', 'race_rating', 'seat', 'seat_name', 'state_id', 'state_slug', 'state_name', 'state_nyt_abbrev', 'state_shape', 'party_id', 'uncontested', 'report', 'result', 'result_source', 'gain', 'lost_seat', 'votes', 'electoral_votes', 'absentee_votes', 'absentee_counties', 'absentee_count_progress', 'absentee_outstanding', 'absentee_max_ballots', 'provisional_outstanding', 'provisional_count_progress', 'poll_display', 'poll_countdown_display', 'poll_waiting_display', 'poll_time', 'poll_time_short', 'precincts_reporting', 'precincts_total', 'reporting_display', 'reporting_value', 'eevp', 'tot_exp_vote', 'eevp_source', 'eevp_value', 'eevp_display', 'county_data_source', 'incumbent_party', 'no_forecast', 'last_updated', 'candidates', 'has_incumbent', 'leader_margin_value', 'leader_margin_votes', 'leader_margin_display', 'leader_margin_name_display', 'leader_party_id', 'counties', 'votes2016', 'margin2016', 'clinton2016', 'trump2016', 'votes2012', 'margin2012', 'expectations_text', 'expectations_text_short', 'absentee_ballot_deadline', 'absentee_postmark_deadline', 'update_sentences', 'race_diff', 'winnerCalledTimestamp', 'timeseries'])

# %%
pres_timeseries = pres_race["timeseries"]
pres_timeseries[0]
# Out:
# {'vote_shares': {'trumpd': 0, 'bidenj': 0},
#  'votes': 0,
#  'eevp': 0,
#  'eevp_source': 'edison',
#  'timestamp': '2020-11-04T10:00:04Z'}

# %%
total_djt_diff = 0
total_jrb_diff = 0

# %%
def print_discrepancy(before_id):
    global total_djt_diff, total_jrb_diff
    
    before_update = pres_timeseries[before_id]
    after_update = pres_timeseries[before_id+1]
    
    votes_djt_before = round(before_update["vote_shares"]["trumpd"] * before_update["votes"])
    votes_jrb_before = round(before_update["vote_shares"]["bidenj"] * before_update["votes"])
    votes_djt_after = round(after_update["vote_shares"]["trumpd"] * after_update["votes"])
    votes_jrb_after = round(after_update["vote_shares"]["bidenj"] * after_update["votes"])

    diff_djt = votes_djt_after - votes_djt_before
    diff_jrb = votes_jrb_after - votes_jrb_before
    diff_total = after_update["votes"] - before_update["votes"]
    
    total_djt_diff += diff_djt
    total_jrb_diff += diff_jrb
    
    
    print("DISCREPANCY DETECTED:\n")
    print("DJT VOTES BEFORE: {}".format(votes_djt_before))
    print("JRB VOTES BEFORE: {}".format(votes_jrb_before))
    print("TOTAL BEFORE: {}".format(before_update["votes"]))
    print("TIMESTAMP BEFORE: {}\n".format(before_update["timestamp"]))

    print("DJT VOTES AFTER: {}".format(votes_djt_after))
    print("JRB VOTES AFTER: {}".format(votes_jrb_after))
    print("TOTAL AFTER: {}".format(after_update["votes"]))
    print("TIMESTAMP AFTER: {}\n".format(after_update["timestamp"]))


    print("DJT DIFF: {}".format(diff_djt))
    print("JRB DIFF: {}".format(diff_jrb))
    print("TOTAL DIFF: {}".format(diff_total))
    print("===================================")

# %%
for i,update in enumerate(pres_timeseries):
    before_update = pres_timeseries[i]
    after_update = pres_timeseries[i+1]
    
    # Calculate vote counts
    votes_djt_before = round(before_update["vote_shares"]["trumpd"] * before_update["votes"])
    votes_jrb_before = round(before_update["vote_shares"]["bidenj"] * before_update["votes"])
    votes_djt_after = round(after_update["vote_shares"]["trumpd"] * after_update["votes"])
    votes_jrb_after = round(after_update["vote_shares"]["bidenj"] * after_update["votes"])
    
    if((votes_djt_after < votes_djt_before) or (votes_jrb_after < votes_jrb_before)):
        print_discrepancy(i)
    
    if(i==len(pres_timeseries)-2):
        break
# Out:
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 1
# JRB VOTES BEFORE: 6
# TOTAL BEFORE: 7
# TIMESTAMP BEFORE: 2020-11-04T00:34:55Z
#
# DJT VOTES AFTER: 0
# JRB VOTES AFTER: 0
# TOTAL AFTER: 0
# TIMESTAMP AFTER: 2020-11-04T00:41:07Z
#
# DJT DIFF: -1
# JRB DIFF: -6
# TOTAL DIFF: -7
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 7
# JRB VOTES BEFORE: 4
# TOTAL BEFORE: 11
# TIMESTAMP BEFORE: 2020-11-04T00:45:12Z
#
# DJT VOTES AFTER: 0
# JRB VOTES AFTER: 0
# TOTAL AFTER: 0
# TIMESTAMP AFTER: 2020-11-04T00:53:56Z
#
# DJT DIFF: -7
# JRB DIFF: -4
# TOTAL DIFF: -11
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 1313012
# JRB VOTES BEFORE: 1686856
# TOTAL BEFORE: 3039380
# TIMESTAMP BEFORE: 2020-11-04T01:15:03Z
#
# DJT VOTES AFTER: 1319534
# JRB VOTES AFTER: 1685224
# TOTAL AFTER: 3047422
# TIMESTAMP AFTER: 2020-11-04T01:15:28Z
#
# DJT DIFF: 6522
# JRB DIFF: -1632
# TOTAL DIFF: 8042
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 1676391
# JRB VOTES BEFORE: 2033470
# TOTAL BEFORE: 3758725
# TIMESTAMP BEFORE: 2020-11-04T01:16:35Z
#
# DJT VOTES AFTER: 1682488
# JRB VOTES AFTER: 2032536
# TOTAL AFTER: 3763956
# TIMESTAMP AFTER: 2020-11-04T01:16:58Z
#
# DJT DIFF: 6097
# JRB DIFF: -934
# TOTAL DIFF: 5231
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 1826656
# JRB VOTES BEFORE: 2084211
# TOTAL BEFORE: 3962378
# TIMESTAMP BEFORE: 2020-11-04T01:23:14Z
#
# DJT VOTES AFTER: 1825859
# JRB VOTES AFTER: 2087830
# TOTAL AFTER: 3969258
# TIMESTAMP AFTER: 2020-11-04T01:24:45Z
#
# DJT DIFF: -797
# JRB DIFF: 3619
# TOTAL DIFF: 6880
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 3429883
# JRB VOTES BEFORE: 3652323
# TOTAL BEFORE: 7175487
# TIMESTAMP BEFORE: 2020-11-04T01:42:46Z
#
# DJT VOTES AFTER: 3429936
# JRB VOTES AFTER: 3645204
# TOTAL AFTER: 7175598
# TIMESTAMP AFTER: 2020-11-04T01:42:55Z
#
# DJT DIFF: 53
# JRB DIFF: -7119
# TOTAL DIFF: 111
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 3672826
# JRB VOTES BEFORE: 3755615
# TOTAL BEFORE: 7526283
# TIMESTAMP BEFORE: 2020-11-04T01:57:04Z
#
# DJT VOTES AFTER: 3666607
# JRB VOTES AFTER: 3749426
# TOTAL AFTER: 7528967
# TIMESTAMP AFTER: 2020-11-04T02:00:12Z
#
# DJT DIFF: -6219
# JRB DIFF: -6189
# TOTAL DIFF: 2684
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 3725932
# JRB VOTES BEFORE: 3771556
# TOTAL BEFORE: 7603943
# TIMESTAMP BEFORE: 2020-11-04T02:10:51Z
#
# DJT VOTES AFTER: 3727162
# JRB VOTES AFTER: 3765195
# TOTAL AFTER: 7606454
# TIMESTAMP AFTER: 2020-11-04T02:12:03Z
#
# DJT DIFF: 1230
# JRB DIFF: -6361
# TOTAL DIFF: 2511
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 4193735
# JRB VOTES BEFORE: 4185246
# TOTAL BEFORE: 8489342
# TIMESTAMP BEFORE: 2020-11-04T02:29:53Z
#
# DJT VOTES AFTER: 4200304
# JRB VOTES AFTER: 4183299
# TOTAL AFTER: 8502640
# TIMESTAMP AFTER: 2020-11-04T02:33:54Z
#
# DJT DIFF: 6569
# JRB DIFF: -1947
# TOTAL DIFF: 13298
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 4366094
# JRB VOTES BEFORE: 4261098
# TOTAL BEFORE: 8749687
# TIMESTAMP BEFORE: 2020-11-04T02:44:28Z
#
# DJT VOTES AFTER: 4378320
# JRB VOTES AFTER: 4255727
# TOTAL AFTER: 8756639
# TIMESTAMP AFTER: 2020-11-04T02:45:42Z
#
# DJT DIFF: 12226
# JRB DIFF: -5371
# TOTAL DIFF: 6952
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 4657936
# JRB VOTES BEFORE: 4382861
# TOTAL BEFORE: 9169166
# TIMESTAMP BEFORE: 2020-11-04T03:16:53Z
#
# DJT VOTES AFTER: 4661940
# JRB VOTES AFTER: 4377452
# TOTAL AFTER: 9177048
# TIMESTAMP AFTER: 2020-11-04T03:17:12Z
#
# DJT DIFF: 4004
# JRB DIFF: -5409
# TOTAL DIFF: 7882
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 4717225
# JRB VOTES BEFORE: 4402743
# TOTAL BEFORE: 9249460
# TIMESTAMP BEFORE: 2020-11-04T03:27:35Z
#
# DJT VOTES AFTER: 4719737
# JRB VOTES AFTER: 4395833
# TOTAL AFTER: 9254386
# TIMESTAMP AFTER: 2020-11-04T03:28:56Z
#
# DJT DIFF: 2512
# JRB DIFF: -6910
# TOTAL DIFF: 4926
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 4749782
# JRB VOTES BEFORE: 4415160
# TOTAL BEFORE: 9295073
# TIMESTAMP BEFORE: 2020-11-04T03:31:59Z
#
# DJT VOTES AFTER: 4767321
# JRB VOTES AFTER: 4413496
# TOTAL AFTER: 9311174
# TIMESTAMP AFTER: 2020-11-04T03:32:55Z
#
# DJT DIFF: 17539
# JRB DIFF: -1664
# TOTAL DIFF: 16101
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 4908893
# JRB VOTES BEFORE: 4480792
# TOTAL BEFORE: 9513359
# TIMESTAMP BEFORE: 2020-11-04T03:45:56Z
#
# DJT VOTES AFTER: 4910061
# JRB VOTES AFTER: 4472343
# TOTAL AFTER: 9515623
# TIMESTAMP AFTER: 2020-11-04T03:46:45Z
#
# DJT DIFF: 1168
# JRB DIFF: -8449
# TOTAL DIFF: 2264
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5108673
# JRB VOTES BEFORE: 4625420
# TOTAL BEFORE: 9862303
# TIMESTAMP BEFORE: 2020-11-04T04:19:33Z
#
# DJT VOTES AFTER: 5116693
# JRB VOTES AFTER: 4622804
# TOTAL AFTER: 9877786
# TIMESTAMP AFTER: 2020-11-04T04:20:09Z
#
# DJT DIFF: 8020
# JRB DIFF: -2616
# TOTAL DIFF: 15483
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5267122
# JRB VOTES BEFORE: 4700983
# TOTAL BEFORE: 10109640
# TIMESTAMP BEFORE: 2020-11-04T04:44:30Z
#
# DJT VOTES AFTER: 5283611
# JRB VOTES AFTER: 4696544
# TOTAL AFTER: 10121861
# TIMESTAMP AFTER: 2020-11-04T04:47:09Z
#
# DJT DIFF: 16489
# JRB DIFF: -4439
# TOTAL DIFF: 12221
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5347527
# JRB VOTES BEFORE: 4772745
# TOTAL BEFORE: 10263968
# TIMESTAMP BEFORE: 2020-11-04T04:59:18Z
#
# DJT VOTES AFTER: 5355395
# JRB VOTES AFTER: 4769488
# TOTAL AFTER: 10279070
# TIMESTAMP AFTER: 2020-11-04T05:00:36Z
#
# DJT DIFF: 7868
# JRB DIFF: -3257
# TOTAL DIFF: 15102
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5420913
# JRB VOTES BEFORE: 4818589
# TOTAL BEFORE: 10384890
# TIMESTAMP BEFORE: 2020-11-04T05:10:39Z
#
# DJT VOTES AFTER: 5422408
# JRB VOTES AFTER: 4809530
# TOTAL AFTER: 10387754
# TIMESTAMP AFTER: 2020-11-04T05:10:57Z
#
# DJT DIFF: 1495
# JRB DIFF: -9059
# TOTAL DIFF: 2864
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5451737
# JRB VOTES BEFORE: 4845989
# TOTAL BEFORE: 10443941
# TIMESTAMP BEFORE: 2020-11-04T05:15:57Z
#
# DJT VOTES AFTER: 5458112
# JRB VOTES AFTER: 4841199
# TOTAL AFTER: 10456154
# TIMESTAMP AFTER: 2020-11-04T05:19:53Z
#
# DJT DIFF: 6375
# JRB DIFF: -4790
# TOTAL DIFF: 12213
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5829602
# JRB VOTES BEFORE: 5170700
# TOTAL BEFORE: 11167819
# TIMESTAMP BEFORE: 2020-11-04T10:49:56Z
#
# DJT VOTES AFTER: 5847549
# JRB VOTES AFTER: 5165521
# TOTAL AFTER: 11180782
# TIMESTAMP AFTER: 2020-11-04T10:56:55Z
#
# DJT DIFF: 17947
# JRB DIFF: -5179
# TOTAL DIFF: 12963
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5881034
# JRB VOTES BEFORE: 5227586
# TOTAL BEFORE: 11266349
# TIMESTAMP BEFORE: 2020-11-06T13:56:48Z
#
# DJT VOTES AFTER: 5883006
# JRB VOTES AFTER: 5218068
# TOTAL AFTER: 11270126
# TIMESTAMP AFTER: 2020-11-06T20:29:33Z
#
# DJT DIFF: 1972
# JRB DIFF: -9518
# TOTAL DIFF: 3777
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5883006
# JRB VOTES BEFORE: 5218068
# TOTAL BEFORE: 11270126
# TIMESTAMP BEFORE: 2020-11-06T20:29:33Z
#
# DJT VOTES AFTER: 5883005
# JRB VOTES AFTER: 5218067
# TOTAL AFTER: 11270124
# TIMESTAMP AFTER: 2020-11-06T21:12:16Z
#
# DJT DIFF: -1
# JRB DIFF: -1
# TOTAL DIFF: -2
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5883269
# JRB VOTES BEFORE: 5218302
# TOTAL BEFORE: 11270630
# TIMESTAMP BEFORE: 2020-11-06T21:25:59Z
#
# DJT VOTES AFTER: 5881251
# JRB VOTES AFTER: 5216512
# TOTAL AFTER: 11266765
# TIMESTAMP AFTER: 2020-11-06T21:55:24Z
#
# DJT DIFF: -2018
# JRB DIFF: -1790
# TOTAL DIFF: -3865
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5881251
# JRB VOTES BEFORE: 5216512
# TOTAL BEFORE: 11266765
# TIMESTAMP BEFORE: 2020-11-06T21:55:24Z
#
# DJT VOTES AFTER: 5878248
# JRB VOTES AFTER: 5213849
# TOTAL AFTER: 11261012
# TIMESTAMP AFTER: 2020-11-06T21:59:31Z
#
# DJT DIFF: -3003
# JRB DIFF: -2663
# TOTAL DIFF: -5753
# ===================================
# DISCREPANCY DETECTED:
#
# DJT VOTES BEFORE: 5878248
# JRB VOTES BEFORE: 5213849
# TOTAL BEFORE: 11261012
# TIMESTAMP BEFORE: 2020-11-06T21:59:31Z
#
# DJT VOTES AFTER: 5870242
# JRB VOTES AFTER: 5206747
# TOTAL AFTER: 11245674
# TIMESTAMP AFTER: 2020-11-06T22:07:47Z
#
# DJT DIFF: -8006
# JRB DIFF: -7102
# TOTAL DIFF: -15338
# ===================================

# %%
print("TOTAL DJT DIFF: {}".format(total_djt_diff))
print("TOTAL JRB DIFF: {}".format(total_jrb_diff))
# Out:
# TOTAL DJT DIFF: 98034
# TOTAL JRB DIFF: -98790
